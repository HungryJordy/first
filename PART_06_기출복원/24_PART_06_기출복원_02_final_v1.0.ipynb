# %% [markdown]
# ## 기출복원 2회

# %% [markdown]
# ### (작업형1)

# %% [markdown]
# #### 1. mtcars2 데이터셋을 불러와 mpg 컬럼의 상위 10번째 값으로 상위 10개 값을 변환한 후 drat가 4 이상인 값에 대해 mpg의 평균을 구하여라. (단, 소수점은 반올림하여 셋째 자리까지 나타낼 것)

# %%
from google.colab import drive
drive.mount('/content/drive')
1234
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('/content/drive/MyDrive/빅분기 실기 2024/data/기출복원/02회/mtcars2.csv')
df1.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8    NaN  175  3.15  3.440  17.02   0   0     3     2

# %%
df1c = df1.copy()
#상위 10번째 값 구하기
df1c_rank = df1c['mpg'].sort_values(ascending=False).reset_index(drop=True)
df1c_rank[9]
# 상위 10개 값을 변환하기
df1c_index = df1c['mpg'].sort_values(ascending=False).index[:10]
df1c['mpg'][df1c_index] = df1c_rank[9]
round(df1c[df1c['drat']>=4]['mpg'].mean(), 3)
# Out:
# <ipython-input-65-e4fc86dffc88>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1c['mpg'][df1c_index] = df1c_rank[9]
# 20.671

# %%
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
#  drat가 4 이상인 값에 대해 mpg의 평균
df1c_mean = df1c[df1c['drat']>=4][df1_rank]
df1c_mean
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 17  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 25  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4    NaN   91  4.43  2.140  16.70   0   1     5     2
# 28  15.8    8    NaN  264  4.22  3.170  14.50   0   1     5     4
# 31  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2

# %%
df1_mpg = df1['mpg'].copy()
df1_drat = df1['drat'].copy()

df1_mpg_sort = df1_mpg.sort_values(ascending = False, ignore_index = True)[9]
df1_mpg_sort

idx = df1_mpg.sort_values()[:10].index
df1_mpg[idx] = df1_mpg_sort

result = round(mpg[df1_drat >= 4].mean(), 3)
result
# Out:
# 20.671

# %%
#### 기출복원 02회 작업형1 01 Solution
import pandas as pd
exam1 = pd.read_csv('data/기출복원/02회/mtcars2.csv')

##### mpg와 drat 컬럼 별도 할당
mpg = exam1['mpg'].copy()
drat = exam1['drat'].copy()

##### mpg 컬럼의 상위 10번째 값
tenth = mpg.sort_values(ascending = False, ignore_index = True)[9]

##### 상위 10번째 값으로 상위 10개 값을 변환
# 상위 10개의 인덱스
idx = mpg.sort_values(ascending = False)[:10].index

# 상위 10개 값 변경
mpg[idx] = tenth

##### drat가 4이상일 때 mpg의 평균
avg_mpg = mpg[drat >= 4].mean()

##### 결과 저장
result = round(avg_mpg, 3)

##### 결과 출력
print(result)
# Out:
# 20.671

# %% [markdown]
# ---

# %% [markdown]
# #### 2. 앞의 데이터셋을 새로 불러와 첫 번째 행부터 순서대로 80%까지의 데이터를 훈련 데이터로 추출한 후 disp 컬럼의 결측값을 disp 컬럼의 중앙값으로 대체하고 대체 전 후의 disp 변수의 표준편차 값의 차이를 구하여라. (단, 차이는 빼는 순서와 관계없이 절댓값을 취하여 표시하고 소수점은 넷째 자리에서 반올림할 것)

# %%
df1_a = df1[:int(df1.shape[0] * 0.8)]

# %%
df1_na = df1_a.copy()
df1_na['disp'] = df1_na['disp'].fillna(df1_na['disp'].median())
df1_na
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  167.6  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  167.6  205  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  167.6  215  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  167.6  150  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3     2

# %%
a = df1_a['disp'].std()
b = df1_na['disp'].std()
round(abs(a-b),3)
# Out:
# 7.966

# %%
#### 기출복원 02회 작업형1 02 Solution
import pandas as pd
import numpy as np
exam2 = pd.read_csv('data/기출복원/02회/mtcars2.csv')

#### 첫 번째 행부터 순서대로 80%까지의 데이터를 훈련 데이터로 추출
# 80%가 되는 행 인덱스 번호 찾기
idx80 = np.floor(exam2.shape[0] * 0.8).astype('int')

# 훈련 데이터 추출
train = exam2[:idx80]

#### disp 변수의 결측값 중앙값으로 대체, 대체 전후 표준편차
# disp 컬럼 할당
disp_before = train['disp'].copy() # 대체하지 않을 것
disp_after = train['disp'].copy() # 대체할 것

# 대체 전(disp_before)의 중앙값과 표준편차
med_before = disp_before.median()
sd_before = disp_before.std()

# 결측치 중앙값 대체
disp_after = disp_after.fillna(med_before)

# 대체 후(disp_after)의 표준편차
sd_after = disp_after.std()

# 차이
diff = abs(sd_before - sd_after)

##### 결과 저장
result = round(diff, 3)

##### 결과 출력
print(result)
# Out:
# 7.966

# %% [markdown]
# ---

# %% [markdown]
# #### 3. gehan 데이터 셋을 불러와 time 컬럼에서 이상값의 합을 구하여라.(단, 이상값은 평균에서 1.5 표준편차 이상으로 벗어난 값으로 정의함)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/빅분기 실기 2024/data/기출복원/02회/gehan.csv')

# %%
df3.head()
# Out:
#    pair  time  cens    treat
# 0     1     1     1  control
# 1     1    10     1     6-MP
# 2     2    22     1  control
# 3     2     7     1     6-MP
# 4     3     3     1  control

# %%
df3_mean = df3['time'].mean()
df3_std = df3['time'].std()
df3_mean
# df3_std
# Out:
# 12.880952380952381

# %%
df3_mean + 1.5 * df3_std
# Out:
# 26.902199945818403

# %%
a=df3['time'][df3['time'] > (df3_mean + 1.5 * df3_std)].sum()
a
# Out:
# 133

# %%
b=df3['time'][df3['time'] < (df3_mean - 1.5 * df3_std)].sum()
b
# Out:
# 0

# %%
a+b
# Out:
# 133

# %%
##### time 컬럼의 평균과 표준편차
time = df3['time']
avg_time = time.mean()
sd_time = time.std()

##### 평균에서 1.5 표준편차 구간
low = avg_time - 1.5 * sd_time
upp = avg_time + 1.5 * sd_time

upp
##### 이상치
# outlier = time[(time < low) | (time > upp)]
# Out:
# 26.902199945818403

# %%
#### 기출복원 02회 작업형1 03 Solution
import pandas as pd
exam3 = pd.read_csv('data/기출복원/02회/gehan.csv')

##### time 컬럼의 평균과 표준편차
time = exam3['time']
avg_time = time.mean()
sd_time = time.std()

##### 평균에서 1.5 표준편차 구간
low = avg_time - 1.5 * sd_time
upp = avg_time + 1.5 * sd_time

##### 이상치
outlier = time[(time < low) | (time > upp)]

##### 결과를 result에 할당
result = sum(outlier)

##### 결과 출력
print(result)
# Out:
# 133

# %% [markdown]
# ---

# %% [markdown]
# ### (작업형2)

# %% [markdown]
# ### 1. 아래는 뇌졸중(stroke)에 대한 환자들의 임상적 변수에 관련한 데이터의 일부이다. 주어진 데이터를 이용하여 예측 모형을 만들고 아래에 따라 CSV 파일을 생성하시오. (단, 제출 전 두 개이상의 모형의 성능을 비교하여 가장 우수한 모형을 선정할 것)

# %%
import pandas as pd

X_train = pd.read_csv('/content/drive/MyDrive/빅분기 실기 2024/data/기출복원/02회/stroke_X_train.csv')
X_test = pd.read_csv('/content/drive/MyDrive/빅분기 실기 2024/data/기출복원/02회/stroke_X_test.csv')
y_train = pd.read_csv('/content/drive/MyDrive/빅분기 실기 2024/data/기출복원/02회/stroke_y_train.csv')
y_test = pd.read_csv('/content/drive/MyDrive/빅분기 실기 2024/data/기출복원/02회/stroke_y_test.csv')

# %%
y_test['stroke'].value_counts()
# Out:
# stroke
# 1    1132
# 0     469
# Name: count, dtype: int64

# %%
X_train.head()
# Out:
#      id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0   678    Male   8.0             0              0           No  children
# 1  1126  Female  65.0             0              0          Yes  Govt_job
# 2  1125  Female  79.0             1              0          Yes   Private
# 3  1016    Male  66.0             0              0          Yes   Private
# 4   948  Female  45.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban              78.48  16.1          Unknown
# 1          Urban              82.72  29.8           smokes
# 2          Rural             119.62  39.0          Unknown
# 3          Rural              67.92  31.1  formerly smoked
# 4          Urban             146.44  22.8  formerly smoked

# %%
y_train
# Out:
#         id  stroke
# 0      678       0
# 1     1126       0
# 2     1125       0
# 3     1016       0
# 4      948       0
# ...    ...     ...
# 2394  2971       1
# 2395  2401       1
# 2396  3313       1
# 2397  1835       1
# 2398  1944       1
#
# [2399 rows x 2 columns]

# %%
range = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# X_train_dummies = pd.get_dummies(X_train, columns=['gender'])
# X_train_dummies

for i in range:
  X_train = pd.get_dummies(X_train, columns = [i])
  X_test = pd.get_dummies(X_test, columns = [i])

# %%
X_train = X_train.drop('id', axis=1)
X_test = X_test.drop('id', axis=1)
print(X_train.info())
print(X_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             2399 non-null   float64
#  1   hypertension                    2399 non-null   int64
#  2   heart_disease                   2399 non-null   int64
#  3   avg_glucose_level               2399 non-null   float64
#  4   bmi                             2399 non-null   float64
#  5   gender_Female                   2399 non-null   bool
#  6   gender_Male                     2399 non-null   bool
#  7   ever_married_No                 2399 non-null   bool
#  8   ever_married_Yes                2399 non-null   bool
#  9   work_type_Govt_job              2399 non-null   bool
#  10  work_type_Never_worked          2399 non-null   bool
#  11  work_type_Private               2399 non-null   bool
#  12  work_type_Self-employed         2399 non-null   bool
#  13  work_type_children              2399 non-null   bool
#  14  Residence_type_Rural            2399 non-null   bool
#  15  Residence_type_Urban            2399 non-null   bool
#  16  smoking_status_Unknown          2399 non-null   bool
#  17  smoking_status_formerly smoked  2399 non-null   bool
#  18  smoking_status_never smoked     2399 non-null   bool
#  19  smoking_status_smokes           2399 non-null   bool
# dtypes: bool(15), float64(3), int64(2)
# memory usage: 129.0 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             1601 non-null   float64
#  1   hypertension                    1601 non-null   int64
#  2   heart_disease                   1601 non-null   int64
#  3   avg_glucose_level               1601 non-null   float64
#  4   bmi                             1601 non-null   float64
#  5   gender_Female                   1601 non-null   bool
#  6   gender_Male                     1601 non-null   bool
#  7   ever_married_No                 1601 non-null   bool
#  8   ever_married_Yes                1601 non-null   bool
#  9   work_type_Govt_job              1601 non-null   bool
#  10  work_type_Never_worked          1601 non-null   bool
#  11  work_type_Private               1601 non-null   bool
#  12  work_type_Self-employed         1601 non-null   bool
#  13  work_type_children              1601 non-null   bool
#  14  Residence_type_Rural            1601 non-null   bool
#  15  Residence_type_Urban            1601 non-null   bool
#  16  smoking_status_Unknown          1601 non-null   bool
#  17  smoking_status_formerly smoked  1601 non-null   bool
#  18  smoking_status_never smoked     1601 non-null   bool
#  19  smoking_status_smokes           1601 non-null   bool
# dtypes: bool(15), float64(3), int64(2)
# memory usage: 86.1 KB
# None

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rc = RandomForestClassifier()
rc.fit(X_train, y_train['stroke'])
rc_pred = rc.predict(X_test)
round(accuracy_score(y_test['stroke'], rc_pred), 3)
# Out:
# 0.962

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train['stroke'])
xgb_pred = xgb.predict(X_test)
round(accuracy_score(y_test['stroke'], xgb_pred), 3)
# Out:
# 0.956

# %%
#### 기출복원 02회 작업형1 01 Solution

##### STEP1. 데이터셋 불러오기
import pandas as pd
X_train = pd.read_csv('data/기출복원/02회/stroke_X_train.csv')
X_test = pd.read_csv('data/기출복원/02회/stroke_X_test.csv')
y_train = pd.read_csv('data/기출복원/02회/stroke_y_train.csv')

# %%
##### STEP2. 데이터셋 확인하기
###### STEP2-1. 데이터셋 일부 확인
print(X_train.head())
print(X_test.head())
print(y_train.head())
# Out:
#      id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0   678    Male   8.0             0              0           No  children
# 1  1126  Female  65.0             0              0          Yes  Govt_job
# 2  1125  Female  79.0             1              0          Yes   Private
# 3  1016    Male  66.0             0              0          Yes   Private
# 4   948  Female  45.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban              78.48  16.1          Unknown
# 1          Urban              82.72  29.8           smokes
# 2          Rural             119.62  39.0          Unknown
# 3          Rural              67.92  31.1  formerly smoked
# 4          Urban             146.44  22.8  formerly smoked
#    id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0   2  Female  78.0             0              0          Yes   Private
# 1   4  Female  59.0             0              0          Yes  Govt_job
# 2   5  Female  59.0             0              0          Yes   Private
# 3   6  Female  33.0             0              0           No   Private
# 4   8    Male  77.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status
# 0          Urban             119.03  31.0     never smoked
# 1          Urban             101.19  29.9  formerly smoked
# 2          Urban             182.52  30.1          Unknown
# 3          Rural              80.21  27.8  formerly smoked
# 4          Urban              71.44  24.1           smokes
#      id  stroke
# 0   678       0
# 1  1126       0
# 2  1125       0
# 3  1016       0
# 4   948       0

# %%
###### STEP2-2. 데이터셋 요약 정보 확인
print(X_train.info())
print(X_test.info())
print(y_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2399 non-null   int64
#  1   gender             2399 non-null   object
#  2   age                2399 non-null   float64
#  3   hypertension       2399 non-null   int64
#  4   heart_disease      2399 non-null   int64
#  5   ever_married       2399 non-null   object
#  6   work_type          2399 non-null   object
#  7   Residence_type     2399 non-null   object
#  8   avg_glucose_level  2399 non-null   float64
#  9   bmi                2399 non-null   float64
#  10  smoking_status     2399 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 206.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1601 non-null   int64
#  1   gender             1601 non-null   object
#  2   age                1601 non-null   float64
#  3   hypertension       1601 non-null   int64
#  4   heart_disease      1601 non-null   int64
#  5   ever_married       1601 non-null   object
#  6   work_type          1601 non-null   object
#  7   Residence_type     1601 non-null   object
#  8   avg_glucose_level  1601 non-null   float64
#  9   bmi                1601 non-null   float64
#  10  smoking_status     1601 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 137.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2399 non-null   int64
#  1   stroke  2399 non-null   int64
# dtypes: int64(2)
# memory usage: 37.6 KB
# None

# %%
###### STEP2-3. 기초통계량 확인
print(X_train.describe())
print(X_test.describe())
print(y_train.describe())
# Out:
#                 id          age  hypertension  heart_disease  \
# count  2399.000000  2399.000000   2399.000000    2399.000000
# mean   2010.176323    60.180492      0.231346       0.154648
# std    1162.012740    19.577115      0.421781       0.361644
# min       1.000000     0.160000      0.000000       0.000000
# 25%     997.500000    51.000000      0.000000       0.000000
# 50%    1999.000000    65.000000      0.000000       0.000000
# 75%    3023.500000    77.000000      0.000000       0.000000
# max    4000.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi
# count        2399.000000  2399.000000
# mean          125.673135    30.187953
# std            59.512953     6.845468
# min            55.120000    13.800000
# 25%            78.800000    26.100000
# 50%           100.540000    29.500000
# 75%           185.170000    33.600000
# max           271.740000    61.600000
#                 id          age  hypertension  heart_disease  \
# count  1601.000000  1601.000000   1601.000000    1601.000000
# mean   1986.000625    60.909032      0.249219       0.148032
# std    1144.228912    19.410576      0.432696       0.355243
# min       2.000000     0.160000      0.000000       0.000000
# 25%    1005.000000    51.000000      0.000000       0.000000
# 50%    2007.000000    67.000000      0.000000       0.000000
# 75%    2963.000000    78.000000      0.000000       0.000000
# max    3999.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi
# count        1601.000000  1601.000000
# mean          126.704941    30.053654
# std            58.661998     6.606219
# min            55.580000    10.300000
# 25%            80.080000    26.000000
# 50%           103.060000    29.400000
# 75%           185.490000    33.600000
# max           271.740000    97.600000
#                 id       stroke
# count  2399.000000  2399.000000
# mean   2010.176323     0.706961
# std    1162.012740     0.455251
# min       1.000000     0.000000
# 25%     997.500000     0.000000
# 50%    1999.000000     1.000000
# 75%    3023.500000     1.000000
# max    4000.000000     1.000000

# %%
##### STEP3. 데이터셋 전처리
###### STEP3-1. 불필요한 컬럼 삭제
# id 컬럼은 환자에 대한 고유 정보로 key 역할로 모델에는 불필요함
# 결과 제출 시에는 X_test의 id 컬럼이 필요하기 때문에 별도 저장
ID = X_test['id'].copy()

# 데이터들에서 id 컬럼 삭제
X_train = X_train.drop(columns = 'id')
X_test = X_test.drop(columns = 'id')
y_train = y_train.drop(columns = 'id')

# %%
###### STEP3-2. 결측치 처리
# 결측치 확인
X_train.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# dtype: int64

# %%
# smoking_status 내 “Unknown”은 정보에 대해 알 수 없는 것으로 결측임
X_train['smoking_status'].value_counts()
# Out:
# never smoked       957
# formerly smoked    548
# Unknown            458
# smokes             436
# Name: smoking_status, dtype: int64

# %%
X_test['smoking_status'].value_counts()
# Out:
# never smoked       632
# formerly smoked    391
# Unknown            291
# smokes             287
# Name: smoking_status, dtype: int64

# %%
###### smoking_status 컬럼 (train:957, test:632 결측)
# 컬럼 삭제
X_train = X_train.drop('smoking_status', axis = 1)
X_test = X_test.drop('smoking_status', axis = 1)

# %%
###### STEP3-3. 카테고리형 컬럼 전처리
#별도 과정이 없으므로 생략

# %%
###### STEP3-4. 수치형 컬럼 전처리
####### age 컬럼
# 비닝하여 파생변수 age_gp에 할당, object형으로 변경
X_train['age_gp'] = pd.cut(X_train['age'], bins = list(range(0,100,10))).astype('object')
X_test['age_gp'] = pd.cut(X_test['age'], bins = list(range(0,100,10))).astype('object')

# 완료 후 삭제
X_train = X_train.drop('age', axis = 1)
X_test = X_test.drop('age', axis = 1)

# %%
###### STEP3-5. 데이터 분할
from sklearn.model_selection import train_test_split

# X_train과 y_train을 학습용(X_TRAIN, y_TRAIN)과 검증용(X_VAL, y_VAL)로 분할
X_TRAIN, X_VAL, y_TRAIN, y_VAL = train_test_split(X_train, y_train, random_state = 1234, test_size = 0.2)

# 분할 후 shape 확인
print(X_TRAIN.shape)
print(X_VAL.shape)
print(y_TRAIN.shape)
print(y_VAL.shape)
# Out:
# (1919, 9)
# (480, 9)
# (1919, 1)
# (480, 1)

# %%
###### STEP3-6. 인코딩
# 카테고리형 컬럼에 대하여 원-핫 인코딩 수행
from sklearn.preprocessing import OneHotEncoder

# 인코딩할 카테고리형 컬럼만 별도 저장
X_TRAIN_category = X_TRAIN.select_dtypes('object').copy()
X_VAL_category = X_VAL.select_dtypes('object').copy()
X_TEST_category = X_test.select_dtypes('object').copy()

# 원-핫 인코딩
enc = OneHotEncoder(sparse = False).fit(X_TRAIN_category)

X_TRAIN_OH = enc.transform(X_TRAIN_category)
X_VAL_OH = enc.transform(X_VAL_category)
X_TEST_OH = enc.transform(X_TEST_category)

# %%
###### STEP3-7. 스케일링
from sklearn.preprocessing import StandardScaler

# 스케일링할 컬럼만 별도 저장
# .select_dtypes() 메소드의 exclude 옵션은 해당 dtype을 제외한 모든 dtype을 추출할 때 사용
X_TRAIN_conti = X_TRAIN.select_dtypes(exclude = 'object').copy()
X_VAL_conti = X_VAL.select_dtypes(exclude = 'object').copy()
X_TEST_conti = X_test.select_dtypes(exclude = 'object').copy()

# TRAIN 데이터 기준으로 스케일링함
scale = StandardScaler().fit(X_TRAIN_conti)

# z-점수 표준화
X_TRAIN_STD = scale.transform(X_TRAIN_conti)
X_VAL_STD = scale.transform(X_VAL_conti)
X_TEST_STD = scale.transform(X_TEST_conti)

# %%
###### STEP3-8. 입력 데이터셋 준비
import numpy as np

# 인코딩과 스케일링된 넘파이 배열 연결
X_TRAIN = np.concatenate([X_TRAIN_OH, X_TRAIN_STD], axis = 1)
X_VAL = np.concatenate([X_VAL_OH, X_VAL_STD], axis = 1)

# 1차원 넘파이 배열로 평탄화
y_TRAIN = y_TRAIN.values.ravel()
y_VAL = y_VAL.values.ravel()

# %%
##### STEP4. 모델 학습
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

###### STEP4-1. random forest
rf = RandomForestClassifier(n_estimators = 500,
                            max_depth = 3,
                            min_samples_leaf = 10,
                            max_features = 2,
                            random_state = 2022)

model_rf = rf.fit(X_TRAIN, y_TRAIN)

###### STEP4-2. XGBoost
xgb = XGBClassifier(max_depth = 8,
                    n_estimators = 500,
                    nthread = 5,
                    min_child_weight = 20,
                    gamma = 0.5,
                    objective = 'binary:logistic',
                    use_label_encoder = False,
                    random_state = 2022)

model_xgb = xgb.fit(X_TRAIN, y_TRAIN, eval_metric = 'mlogloss')

###### STEP4-3. LightGBM
lgb = LGBMClassifier(max_depth = 8,
                     n_estimators = 500,
                     n_jobs = 30,
                     min_child_weight = 10,
                     learning_rate = 0.2,
                     objective = 'binary',
                     random_state = 2022)

model_lgb = lgb.fit(X_TRAIN, y_TRAIN)
# Out:
# c:\Users\Administrator\anaconda3\envs\big_ana\lib\site-packages\xgboost\compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
###### STEP4-4. 성능평가(기준:accuracy_score)를 통한 모델 선정
from sklearn.metrics import accuracy_score

# 검증용 데이터셋을 통한 예측
pred_rf = model_rf.predict(X_VAL)
pred_xgb = model_xgb.predict(X_VAL)
pred_lgb = model_lgb.predict(X_VAL)

# accuracy 계산
acc_rf = accuracy_score(y_VAL, pred_rf)
print(acc_rf)

acc_xgb = accuracy_score(y_VAL, pred_xgb)
print(acc_xgb)

acc_lgb = accuracy_score(y_VAL, pred_lgb)
print(acc_lgb)
# Out:
# 0.7583333333333333
# 0.9
# 0.9208333333333333

# %%
##### STEP5. 결과 제출하기
###### 실제 시험에서 답 제출시에는 성능이 가장 우수한 모형 하나만 구현!
X_TEST = np.concatenate([X_TEST_OH, X_TEST_STD], axis = 1)
y_pred = model_lgb.predict(X_TEST)

# 문제에서 요구하는 형태로 변환 필요
obj = {'id' : ID,
       'stroke' : y_pred}
result = pd.DataFrame(obj)

# result.csv로 제출하기
result.to_csv("result.csv", index = False)

# %%
##### STEP6. 채점 모델 평가(번외)
# 실제값
actual = pd.read_csv('data/기출복원/02회/stroke_y_test.csv')
actual = actual['stroke'].ravel()

# 채점 기준이 될 성과지표 값
accuracy_score(actual, y_pred)
# Out:
# 0.9350405996252342

# %% [markdown]
# # (끝)
